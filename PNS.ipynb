# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_PNS.csv')

# %%
df.head()
# Out:
#    UF  Situação Censitária  Área  Sabe o peso?  Peso Informado  Peso Final  \
# 0  11                    1     1           1.0            60.0        60.0
# 1  11                    1     1           1.0            65.0        65.0
# 2  11                    1     1           1.0            77.0        77.0
# 3  11                    1     1           2.0             NaN        56.0
# 4  11                    1     1           1.0            55.0        55.0
#
#    Quanto tempo da última vez que pesou?  Sabe a altura?  Altura Informada  \
# 0                                    2.0             1.0             145.0
# 1                                    2.0             1.0             152.0
# 2                                    2.0             1.0             155.0
# 3                                    1.0             2.0               NaN
# 4                                    1.0             1.0             176.0
#
#    Altura Final  ...  \
# 0         145.0  ...
# ...

# %%
df.shape
# Out:
# (90846, 149)
