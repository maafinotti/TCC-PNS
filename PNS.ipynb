# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_PNS.csv')

# %%
df.head()
# Out:
#    UF  Situação Censitária  Área  Peso Final  Altura Final  Está grávida?  \
# 0  11                    1     1        60.0         145.0            2.0
# 1  11                    1     1        65.0         152.0            2.0
# 2  11                    1     1        77.0         155.0            2.0
# 3  11                    1     1        56.0         159.0            2.0
# 4  11                    1     1        55.0         176.0            2.0
#
#    Em quantos dias da semana costuma comer feijão?  \
# 0                                              7.0
# 1                                              7.0
# 2                                              7.0
# 3                                              7.0
# 4                                              3.0
#
#    Em quantos dias da semana, costuma comer pelo menos um tipo de verdura ou legume (sem contar batata, mandioca, cará ou inhame)?  \
# 0                                                1.0
# ...

# %%
df.shape
# Out:
# (90846, 104)

# %%
df.groupby('UF').size().sort_values(ascending=False)
# Out:
# UF
# 35    6114
# 31    5209
# 21    5080
# 33    4966
# 23    4265
# 26    4083
# 41    3967
# 15    3853
# 43    3767
# 42    3738
# 29    3659
# 32    3541
# 13    3479
# 25    3158
# 27    2987
# 24    2962
# 50    2863
# 22    2740
# 52    2702
# 28    2610
# 51    2468
# 12    2380
# 53    2365
# 14    2238
# 11    2176
# 17    1922
# 16    1554
# dtype: int64

# %%
filtro = (df['Área'] == 1)
df[ filtro ].groupby('UF').size().sort_values(ascending=False)
# Out:
# UF
# 35    2647
# 53    2365
# 33    1927
# 13    1635
# 31    1577
# 50    1370
# 14    1351
# 27    1291
# 12    1275
# 29    1220
# 25    1137
# 15    1088
# 22    1071
# 41    1069
# 43    1068
# 52    1025
# 26    1018
# 32    1015
# 11     989
# 24     946
# 21     906
# 51     906
# 23     883
# 28     870
# 16     866
# 42     814
# 17     584
# dtype: int64
